# %% [markdown]
# # 🐈 SERVICES & RATES
# ## What Will Happen During a Visit
# Visits are adapted to your personality, not a checklist.
# ____
#
# ::::{grid} 2
# :class: responsive-grid
#
# :::{grid-item}
# ### 30-Minute Visit — $20
# *Suitable for cats who prefer efficiency*
#
# I will:
# - Make food appear
# - Refresh water
# - Clean the litter box
# - Offer play, petting, or quiet coexistence
# :::
#
# :::{grid-item}
# ```{image} images/30min.png
# :width: 200px
# :::
#
# ::::
#
# ___
#
# ::::{grid} 2
# :class: responsive-grid
#
# :::{grid-item}
# ### 30-Minute Visit — $20
# *Suitable for cats who prefer efficiency*
#
# I will:
# - Make food appear
# - Refresh water
# - Clean the litter box
# - Offer play, petting, or quiet coexistence
# :::
#
# :::{grid-item}
# ```{image} images/30min.png
# :width: 200px
# :::
#
# ::::
#
# ___
#
# ### 45-Minute Visit — $25
# *Suitable for cats who value company*
#
# I will:
# - Do all of the above
# - Stay longer to provide additional playtime, petting or calm company.
# ____
# ### Free Updates - $0
# *To help your human relax*
#
# Your human worries and misses you. This is normal and expected.
# For no extra fee, I will:
# - Report to your human that all is well
# - I will send photos and short videos so they know you remain in control of the situation
#
# This service is for them. You may ignore it.
